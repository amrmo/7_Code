# %%
import numpy as np
import tensorflow as tf

# %%
# code(1) slide(90)
N,D,H =64,100,100
x=tf.placeholder(tf.float32,shape=(N,D))
y=tf.placeholder(tf.float32,shape=(N,D))
w1=tf.placeholder(tf.float32,shape=(D,H))
w2=tf.placeholder(tf.float32,shape=(H,D))

h=tf.maximum(tf.matmul(x,w1),0)
y_pred=tf.matmul(h,w2)
diff=y_pred-y
loss=tf.reduce_mean(tf.reduce_sum(diff**2,axis=1))

grad_w1, grad_w2=tf.gradients(loss, [w1,w2])

with tf.Session() as sess:
    values={x:np.random.randn(N,D),
            w1:np.random.randn(D,H),
            w2:np.random.randn(H,D),
            y:np.random.randn(N,D)}
    out=sess.run([loss,grad_w1,grad_w2],feed_dict=values)
    loss_val,grad_w1_val,grad_w2_val=out
    print(loss_val)
# Out:
# 516388.97

# %%
# code(2) slide(99)
N,D,H =64,100,100
x=tf.placeholder(tf.float32,shape=(N,D))
y=tf.placeholder(tf.float32,shape=(N,D))
w1=tf.placeholder(tf.float32,shape=(D,H))
w2=tf.placeholder(tf.float32,shape=(H,D))

h=tf.maximum(tf.matmul(x,w1),0)
y_pred=tf.matmul(h,w2)
diff=y_pred-y
loss=tf.reduce_mean(tf.reduce_sum(diff**2,axis=1))

grad_w1, grad_w2=tf.gradients(loss, [w1,w2])

with tf.Session() as sess:
    values={x:np.random.randn(N,D),
            w1:np.random.randn(D,H),
            w2:np.random.randn(H,D),
            y:np.random.randn(N,D)}
    learning_rate=1e-5
    for t in range(5000):
        out=sess.run([loss,grad_w1,grad_w2],feed_dict=values)
        loss_val,grad_w1_val,grad_w2_val=out
        values[w1]-=learning_rate*grad_w1_val
        values[w2]-=learning_rate*grad_w2_val
        print(loss_val)
# Out:
# 484067.47
# 466742.75
# 450691.3
# 435784.56
# 421911.0
# 408973.8
# 396884.75
# 385573.5
# 374971.78
# 365016.06
# 355652.44
# 346831.8
# 338498.3
# 330626.7
# 323169.38
# 316098.8
# 309383.62
# 303000.75
# 296924.3
# 291132.28
# 285604.56
# 280323.84
# 275271.0
# 270431.44
# 265791.12
# 261336.47
# 257056.0
# 252938.27
# 248968.92
# 245145.12
# 241457.47
# 237897.0
# 234456.97
# 231131.52
# 227912.34
# 224793.6
# 221771.05
# 218838.69
# 215995.62
# 213233.84
# 210549.31
# 207938.7
# 205398.0
# 202923.78
# 200513.55
# 198164.42
# 195872.08
# 193634.5
# 191449.16
# 189315.22
# 187230.06
# 185192.1
# 183198.2
# 181247.05
# 179336.4
# 177465.48
# 175632.11
# 173835.03
# 172072.16
# 170344.22
# 168649.17
# 166987.12
# 165356.78
# 163756.97
# 162185.66
# 160642.88
# 159128.27
# 157640.66
# 156178.78
# 154741.7
# 153328.58
# 151939.7
# 150573.81
# 149230.67
# 147909.17
# 146608.39
# 145328.38
# 144068.45
# 142828.39
# 141607.31
# 140405.38
# 139221.53
# 138056.03
# 136906.62
# 135774.22
# ...

# %%
# code(3) slide(101)
N,D,H =64,100,100
x=tf.placeholder(tf.float32,shape=(N,D))
y=tf.placeholder(tf.float32,shape=(N,D))
w1=tf.Variable(tf.random_normal((D,H)))
w2=tf.Variable(tf.random_normal((H,D)))

h=tf.maximum(tf.matmul(x,w1),0)
y_pred=tf.matmul(h,w2)
diff=y_pred-y
loss=tf.reduce_mean(tf.reduce_sum(diff**2,axis=1))
grad_w1, grad_w2=tf.gradients(loss, [w1,w2])

learning_rate=1e-5
new_w1=w1.assign(w1-learning_rate*grad_w1)
new_w2=w1.assign(w2-learning_rate*grad_w2)


with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    values={x:np.random.randn(N,D),
            y:np.random.randn(N,D)}
    for t in range(50):
        loss_val=sess.run([loss],feed_dict=values)
        print(loss_val)
# Out:
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]
# [504468.44]

# %%
# code(4) slide(105) or use updates
N,D,H =64,100,100
x=tf.placeholder(tf.float32,shape=(N,D))
y=tf.placeholder(tf.float32,shape=(N,D))
w1=tf.Variable(tf.random_normal((D,H)))
w2=tf.Variable(tf.random_normal((H,D)))

h=tf.maximum(tf.matmul(x,w1),0)
y_pred=tf.matmul(h,w2)
diff=y_pred-y
loss=tf.reduce_mean(tf.reduce_sum(diff**2,axis=1))
grad_w1, grad_w2=tf.gradients(loss, [w1,w2])

learning_rate=1e-5
new_w1=w1.assign(w1-learning_rate*grad_w1)
new_w2=w1.assign(w2-learning_rate*grad_w2)
updates=tf.group(new_w1,new_w2)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    values={x:np.random.randn(N,D),
            y:np.random.randn(N,D)}
    losses=[]
    for t in range(50):
        #loss_val,new_w1_val,new_w2_val=sess.run([loss,new_w1,new_w2],feed_dict=values)
        loss_val,_=sess.run([loss,updates],feed_dict=values)
        print(loss_val)
# Out:
# 530816.75
# 501104.5
# 496292.5
# 496340.72
# 496340.2
# 496340.22
# 496340.22
# 496340.22
# 496340.22
# 496340.22
# 496340.22
# 496340.22
# 496340.22
# 496340.22
# 496340.22
# 496340.22
# 496340.22
# 496340.22
# 496340.22
# 496340.22
# 496340.22
# 496340.22
# 496340.22
# 496340.22
# 496340.22
# 496340.22
# 496340.22
# 496340.22
# 496340.22
# 496340.22
# 496340.22
# 496340.22
# 496340.22
# 496340.22
# 496340.22
# 496340.22
# 496340.22
# 496340.22
# 496340.22
# 502440.88
# 502428.8
# 496277.2
# 496341.22
# 496340.47
# 496340.5
# 496340.5
# 496340.5
# 496340.5
# 496340.5
# 496340.5

# %%
# code(5) slide(106)
N,D,H =64,100,100
x=tf.placeholder(tf.float32,shape=(N,D))
y=tf.placeholder(tf.float32,shape=(N,D))
w1=tf.Variable(tf.random_normal((D,H)))
w2=tf.Variable(tf.random_normal((H,D)))

h=tf.maximum(tf.matmul(x,w1),0)
y_pred=tf.matmul(h,w2)
diff=y_pred-y
loss=tf.reduce_mean(tf.reduce_sum(diff**2,axis=1))

optimizer=tf.train.GradientDescentOptimizer(1e-5)
updates=optimizer.minimize(loss)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    values={x:np.random.randn(N,D),
            y:np.random.randn(N,D)}
    losses=[]
    for t in range(50):
        loss_val,_=sess.run([loss,updates],feed_dict=values)
        print(loss_val)
# Out:
# 501501.38
# 481936.8
# 463856.56
# 447112.94
# 431577.75
# 417141.88
# 403699.5
# 391156.7
# 379430.25
# 368451.0
# 358156.1
# 348487.47
# 339392.53
# 330823.78
# 322738.25
# 315101.94
# 307878.7
# 301037.4
# 294549.5
# 288391.94
# 282539.06
# 276967.38
# 271656.6
# 266588.62
# 261745.73
# 257115.92
# 252683.67
# 248435.6
# 244360.33
# 240446.53
# 236680.53
# 233057.4
# 229568.4
# 226204.36
# 222958.36
# 219824.03
# 216794.86
# 213865.28
# 211030.3
# 208284.03
# 205622.47
# 203038.84
# 200530.89
# 198094.12
# 195726.11
# 193423.36
# 191181.58
# 188997.38
# 186868.1
# 184792.56

# %%
# code(6) slide(107)
N,D,H =64,100,100
x=tf.placeholder(tf.float32,shape=(N,D))
y=tf.placeholder(tf.float32,shape=(N,D))
w1=tf.Variable(tf.random_normal((D,H)))
w2=tf.Variable(tf.random_normal((H,D)))

h=tf.maximum(tf.matmul(x,w1),0)
y_pred=tf.matmul(h,w2)

loss=tf.losses.mean_squared_error(y_pred,y)

optimizer=tf.train.GradientDescentOptimizer(1e-5)
updates=optimizer.minimize(loss)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    values={x:np.random.randn(N,D),
            y:np.random.randn(N,D)}
    losses=[]
    for t in range(50):
        loss_val,_=sess.run([loss,updates],feed_dict=values)
        print(loss_val)
# Out:
# 5096.183
# 5094.23
# 5092.2754
# 5090.328
# 5088.3813
# 5086.438
# 5084.4937
# 5082.549
# 5080.607
# 5078.6694
# 5076.728
# 5074.7915
# 5072.856
# 5070.923
# 5068.9897
# 5067.058
# 5065.127
# 5063.1997
# 5061.2715
# 5059.349
# 5057.424
# 5055.499
# 5053.5786
# 5051.6606
# 5049.741
# 5047.8223
# 5045.9097
# 5043.9976
# 5042.0845
# 5040.172
# 5038.26
# 5036.3555
# 5034.4507
# 5032.5444
# 5030.644
# 5028.739
# 5026.839
# 5024.941
# 5023.04
# 5021.147
# 5019.252
# 5017.358
# 5015.4663
# 5013.573
# 5011.6875
# 5009.8037
# 5007.913
# 5006.031
# 5004.146
# 5002.2637

# %%
# code(7) slide(108)
N,D,H =64,100,100
x=tf.placeholder(tf.float32,shape=(N,D))
y=tf.placeholder(tf.float32,shape=(N,D))

init=tf.variance_scaling_initializer(2.0)
h=tf.layers.dense(inputs=x, units=H, activation=tf.nn.relu,kernel_initializer=init)
y_pred=tf.layers.dense(inputs=h, units=D,kernel_initializer=init)

loss=tf.losses.mean_squared_error(y_pred,y)

optimizer=tf.train.GradientDescentOptimizer(1e-5)
updates=optimizer.minimize(loss)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    values={x:np.random.randn(N,D),
            y:np.random.randn(N,D)}
    losses=[]
    for t in range(50):
        loss_val,_=sess.run([loss,updates],feed_dict=values)
        print(loss_val)
# Out:
# 3.065078
# 3.065058
# 3.0650384
# 3.0650182
# 3.0649981
# 3.06498
# 3.0649602
# 3.0649395
# 3.0649216
# 3.0649014
# 3.0648835
# 3.0648634
# 3.0648432
# 3.0648253
# 3.0648065
# 3.0647871
# 3.0647674
# 3.0647473
# 3.0647295
# 3.0647085
# 3.0646896
# 3.0646706
# 3.064652
# 3.0646331
# 3.0646143
# 3.0645943
# 3.0645752
# 3.064556
# 3.064536
# 3.0645175
# 3.0644982
# 3.0644794
# 3.06446
# 3.0644405
# 3.0644217
# 3.064403
# 3.0643835
# 3.0643659
# 3.0643456
# 3.0643265
# 3.0643084
# 3.064287
# 3.0642688
# 3.064248
# 3.0642285
# 3.0642102
# 3.06419
# 3.0641704
# 3.064151
# 3.0641315

# %%
#code(8) in slide(109)
N,D,H =64,100,100
x=tf.placeholder(tf.float32,shape=(N,D))
y=tf.placeholder(tf.float32,shape=(N,D))

model=tf.keras.Sequential()
model.add(tf.keras.layers.Dense(H, input_shape=(D,), activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(D))
y_pred=model(x)
loss=tf.losses.mean_squared_error(y_pred,y)

optimizer=tf.train.GradientDescentOptimizer(1e-5)
updates=optimizer.minimize(loss)
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    values={x:np.random.randn(N,D),
            y:np.random.randn(N,D)}
    losses=[]
    for t in range(50):
        loss_val,_=sess.run([loss,updates],feed_dict=values)
        print(loss_val)
# Out:
# 1.555739
# 1.5557362
# 1.5557336
# 1.5557308
# 1.555728
# 1.5557249
# 1.5557224
# 1.5557196
# 1.5557171
# 1.5557144
# 1.555712
# 1.5557092
# 1.5557065
# 1.5557038
# 1.5557013
# 1.5556982
# 1.5556954
# 1.5556927
# 1.5556899
# 1.5556871
# 1.5556843
# 1.5556815
# 1.5556787
# 1.555676
# 1.5556732
# 1.55567
# 1.5556675
# 1.5556647
# 1.5556619
# 1.5556593
# 1.5556566
# 1.5556537
# 1.5556512
# 1.5556484
# 1.5556457
# 1.555643
# 1.5556402
# 1.5556376
# 1.5556343
# 1.5556319
# 1.5556288
# 1.5556264
# 1.5556238
# 1.5556213
# 1.5556185
# 1.5556158
# 1.5556132
# 1.5556107
# 1.5556079
# 1.5556048

# %%
#code(9) in slide(111)
N,D,H=64,1000,100
model=tf.keras.Sequential()
model.add(tf.keras.layers.Dense(H,input_shape=(D,), activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(D))
model.compile(loss=tf.keras.losses.mean_squared_error,optimizer=tf.keras.optimizers.SGD(lr=1e0))
x=np.random.randn(N,D)
y=np.random.randn(N,D)
history=model.fit(x,y,epochs=5000,batch_size=N)
# Out:
# Epoch 1/5000
# 64/64 [==============================] - 1s 21ms/step - loss: 1.1697
# Epoch 2/5000
# 64/64 [==============================] - 0s 359us/step - loss: 1.1317
# Epoch 3/5000
# 64/64 [==============================] - 0s 656us/step - loss: 1.1020
# Epoch 4/5000
# 64/64 [==============================] - 0s 563us/step - loss: 1.0783
# Epoch 5/5000
# 64/64 [==============================] - 0s 438us/step - loss: 1.0589
# Epoch 6/5000
# 64/64 [==============================] - 0s 594us/step - loss: 1.0428
# Epoch 7/5000
# 64/64 [==============================] - 0s 422us/step - loss: 1.0292
# Epoch 8/5000
# 64/64 [==============================] - 0s 406us/step - loss: 1.0177
# Epoch 9/5000
# 64/64 [==============================] - 0s 359us/step - loss: 1.0079
# Epoch 10/5000
# 64/64 [==============================] - 0s 500us/step - loss: 0.9994
# Epoch 11/5000
# 64/64 [==============================] - 0s 328us/step - loss: 0.9920
# Epoch 12/5000
# ...

# %%
import tensorflow as tf 
import numpy as np

# %%
input_layer=1
hidden_layer=2
output_layer=1

# %%
model=tf.keras.Sequential()
model.add(tf.keras.layers.Dense(input_layer,input_shape=(1,),activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(hidden_layer,activation=tf.nn.relu))

model.add(tf.keras.layers.Dense(output_layer,activation=tf.nn.relu))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_3 (Dense)              (None, 1)                 2
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 4
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 3
# ...
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________

# %%
model=tf.keras.Sequential()
model.add(tf.keras.layers.Dense(input_layer,input_shape=(1,),activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(hidden_layer,activation=tf.nn.relu))

model.add(tf.keras.layers.Dense(output_layer,activation=tf.nn.relu))
model.summary()

model.compile(loss=tf.keras.losses.mean_squared_error,optimizer=tf.keras.optimizers.SGD(lr=1e-1))

x=np.random.randn(100,1)
y=np.random.randn(100,1)
model.fit(x,y,epochs=5000,batch_size=100)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_12 (Dense)             (None, 1)                 2
# _________________________________________________________________
# dense_13 (Dense)             (None, 2)                 4
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 3
# ...
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5000
# 100/100 [==============================] - 1s 8ms/step - loss: 1.0942
# Epoch 2/5000
# 100/100 [==============================] - 0s 30us/step - loss: 1.0942
# Epoch 3/5000
# 100/100 [==============================] - 0s 40us/step - loss: 1.0942
# Epoch 4/5000
# 100/100 [==============================] - 0s 40us/step - loss: 1.0942
# Epoch 5/5000
# ...
